# %% [markdown]
# # 1 Exploratory Data Analysis

# %% [markdown]
# # 2 데이터셋 출처

# %% [markdown]
# ### 2.1 데이터 구성
# * Pregnancies : 임신횟수
# * Glucose : 2시간 동안의 경구 포도당 내성 검사에서 혈장 포도당 농도
# * BloodPressure : 이완기 혈압(mm Hg)
# * SkinThickness  :SkinThicknessTriceps 피부 주름 두께(mm)
# * Insulin : 2시간 혈청 인슐린(mu U / ml)
# * BMI : 체질량 지수(체중kg / 키(m)^2)
# * DiabetesPedigreeFunction : 당뇨병 혈통 기능
# * Age : 나이
# * Outcome : 768개 중에 268개의 결과 클래스 변수(0 또는 1)는 1이고 나머지는 0 입니다.

# %% [markdown]
# # 3 라이브러리 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='Malgun Gothic')
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # FutureWarning 제거

# %% [markdown]
# # 4 데이터 로드

# %%
df=pd.read_csv('../data/diabetes.csv')
df.shape
# Out:
# (768, 9)

# %%
# 5개만 미리보기 
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# info로 데이터타입, 결측치, 메모리 사용량 등의 정보
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 결측치 보기
df_null=df.isnull()
df_null
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
# 결측치가 없음
df_null.sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# 수치데이터에 대한 요약
df.describe(include="number")
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Outcome은  label 값이기 때문에 제외하고
# 학습과 예측에 사용할 컬럼을 만들어 줍니다.
# feature_columns 라는 변수에 담아줍니다.
feature_columns =df.columns[:-1].tolist()

# %%
cols=feature_columns[1:]
cols
# Out:
# ['Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %% [markdown]
# # 5 결측치 시각화
# 값을 요약해 보면 최솟값이 0으로 나오는 값들이 있습니다. 0이 나올 수 있는 값도 있지만 인슐린이나 혈압 등의 값은 0값이 결측치라고 볼 수 있을 것입니다.</br>
# 따라서 0인 값을  결측치로 처리하고 시각화 해봅시다.

# %%
# 결측치 여부를 나타내는 데이터 프레임을 만듭니다.
# 0값을 결측치라 가정하고 정답(label, target)값을 제외한 컬럼에 대해
# 결측치 여부를 구해서 df_null 이라는 데이터프레임에 담습니다.
df_null=df[cols].replace(0, np.nan)
df_null=df_null.isnull()
df_null.sum()
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
df_null.mean() * 100
# Out:
# Glucose                      0.651042
# BloodPressure                4.557292
# SkinThickness               29.557292
# Insulin                     48.697917
# BMI                          1.432292
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# dtype: float64

# %%
# 결측치의 갯수를 구해 막대 그래프로 시각화 합니다.
df_null.sum().plot.barh()
plt.show()

# %%
# 결측치를 heatmap 으로 시각화 합니다.
plt.figure(figsize=(15,5))
sns.heatmap(df_null,cmap="Greys_r")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6 정답값
# * target, label 이라고 부르기도 합니다.

# %%
# 정답값인 Outcome 의 갯수를 봅니다.
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# 정답값인 Outcome 의 비율을 봅니다.
df["Outcome"].value_counts(normalize=True)
# Out:
# 0    0.651042
# 1    0.348958
# Name: Outcome, dtype: float64

# %%
# 다른 변수와 함께 봅니다.
# 임신횟수와 정답값을 비교해 봅니다.
# "Pregnancies"를 groupby 로 그룹화 해서 Outcome 에 대한 비율을 구합니다.
# 결과를 df_po라는 벼눗에 저장합니다.
df_po=df.groupby(['Pregnancies'])['Outcome'].agg(['mean','count']).reset_index()
df_po
# Out:
#     Pregnancies      mean  count
# 0             0  0.342342    111
# 1             1  0.214815    135
# 2             2  0.184466    103
# 3             3  0.360000     75
# 4             4  0.338235     68
# 5             5  0.368421     57
# 6             6  0.320000     50
# 7             7  0.555556     45
# 8             8  0.578947     38
# 9             9  0.642857     28
# 10           10  0.416667     24
# 11           11  0.636364     11
# 12           12  0.444444      9
# 13           13  0.500000     10
# 14           14  1.000000      2
# 15           15  1.000000      1
# 16           17  1.000000      1

# %%
# 임신횟수에 따른 당뇨병 발병 비율
df_po['mean'].plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7 Countplot

# %%
# 위에서 구했던 당뇨병 발병 비율을 구해본디ㅏ.
# 당뇨병 발병 빈도수를 비교 합니다.
sns.countplot(data=df, x="Outcome")
plt.show()

# %%
# 임신횟수에 따른 당뇨병 발병 빈도수를 비교합니다.
sns.countplot(data=df, x='Pregnancies',hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %%
# 임신횟수의 많고 적음에 따라 Pregnancies_high 변수를 만듭니다.
df["Pregnancies_high"]=df['Pregnancies'] >6
df[["Pregnancies", "Pregnancies_high"]]
# Out:
#      Pregnancies  Pregnancies_high
# 0              6             False
# 1              1             False
# 2              8              True
# 3              1             False
# 4              0             False
# ..           ...               ...
# 763           10              True
# 764            2             False
# 765            5             False
# 766            1             False
# 767            1             False
#
# [768 rows x 2 columns]

# %%
# Pregnancies_high 변수의 빈도수를 countplot 으로 그리고
# Outcome 값에 따라 다른 색상으로 표현합니다.
sns.countplot(data=df, x='Pregnancies_high', hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies_high', ylabel='count'>

# %% [markdown]
# # 8 barplot
# * 기본 설정으로 시각화 하면 y축에는 평균을 추정해서 그리게 됩니다.

# %%
# 당뇨병 발병에 따라 BMI 수치를 비교합니다.
sns.barplot(data=df, x="Outcome", y="BMI")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BMI'>

# %%
# 당뇨병 발병에 따른 포도당(Glucose)수치를 비교합니다.
sns.barplot(data=df, x="Outcome", y="Glucose")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Glucose'>

# %%
# Insulin 수치가 0이상인 관측치에 대해서 당뇨병 발병을 비교합니다.
sns.barplot(data=df, x="Outcome", y="Insulin")
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Insulin'>

# %%
# 임신횟수에 대해서 당뇨병 발병 비율을 비교합니다,
sns.barplot(data=df, x="Pregnancies", y="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Outcome'>

# %%
# 임신횟수(Pregnancies)에 따른 포도당(Glucose)수치를 당뇨병 발병여부(Outcome)에 따라 시각화 합니다.
sns.barplot(data=df, x="Pregnancies", y="Glucose", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Glucose'>

# %%
# 임신횟수(Pregnancies)에 따른 체질량지수(BMI)를 당뇨병 발병여부(Outcome)에 따라 시각화 합니다.
sns.barplot(data=df, x="Pregnancies", y="BMI", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='BMI'>

# %%
# 임신횟수(Pregnancies)에 따른 인슐린(Insulin)수치를 당뇨병 발병여부(Outcome)에 따라 시각화 합니다.
# 인슐린 수치에는 결측치가 많기 때문에 0보다 큰 값에 대해서만 그립니다.
sns.barplot(data=df[df["Insulin"]>0], x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# # 9 boxplot

# %%
# 임신횟수(Pregnancies)에 따른 인슐린(Insulin)수치를 당뇨병 발병여부(Outcome)에 따라 시각화 합니다.
# 인슐린 수치에는 결측치가 많기 때문에 0보다 큰 값에 대해서만 그립니다.
sns.boxplot(data=df[df['Insulin']>0], x="Pregnancies", y="Insulin", hue="Outcome")
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>

# %% [markdown]
# # 10 violinplot

# %%
# 임신횟수(Pregnancies)에 따른 인슐린(Insulin)수치를 당뇨병 발병여부(Outcome)에 따라 시각화 합니다.
# 인슐린 수치에는 결측치가 많기 때문에 0보다 큰 값에 대해서만 그립니다.
plt.figure(figsize=(15,4))
sns.violinplot(data=df[df['Insulin']>0], x="Pregnancies", y="Insulin", hue="Outcome",split=True)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Insulin'>
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 11 swarmplot

# %%
# 임신횟수(Pregnancies)에 따른 인슐린(Insulin)수치를 당뇨병 발병여부(Outcome)에 따라 시각화 합니다.
# 인슐린 수치에는 결측치가 많기 때문에 0보다 큰 값에 대해서만 그립니다.
plt.figure(figsize=(15,4))
sns.swarmplot(data=df[df['Insulin']>0], x="Pregnancies", y="Insulin", hue="Outcome")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 27.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 12 distplot

# %%
df_0=df[df["Outcome"] == 0]
df_1=df[df["Outcome"] == 1]
df_0.shape, df_1.shape
# Out:
# ((500, 10), (268, 10))

# %%
# 임신횟수에 따른 당뇨병 발병 여부를 시각화 합니다.
sns.distplot(df_0["Pregnancies"])
sns.distplot(df_1["Pregnancies"])
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='Density'>

# %%
# 나이에 따른 당뇨병 발병 여부를 시각화 합니다.
sns.distplot(df_0["Age"], hist=False, rug=True, label=0)
sns.distplot(df_1["Age"], hist=False, rug=True, label=1)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# # 13 subplot

# %% [markdown]
# ### 13.1 Pandas 를 통한 histplot 그리기
# * pandas를 사용하면 모든 변수에 대한 서브플롯을 한 번에 그려줍니다.

# %%
df["Pregnancies_high"]=df["Pregnancies_high"].astype(int)
h=df.hist(figsize=(15,15), bins=20)

# %% [markdown]
# ### 13.2 반복문을 통한 서브플롯 그리기

# %% [markdown]
# #### 13.2.1 distplot

# %%
# 컬럼의 수 만큼 for 문을 만들어서 서브플롯으로 시각화를 합니다.
cols=df.columns[:-1].tolist()
cols
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
# distplot 으로 서브플롯을 그립니다.

fig, axes= plt.subplots(nrows=3, ncols=3, figsize=(15,15))
for i, col_name in enumerate(cols):
    row=i // 3
    col=i % 3
    sns.distplot(df[col_name], ax=axes[row][col])
    
# sns.distplot(df["Outcome"], ax=axes[1][1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df[df["Outcome"]== 0]
df[df["Outcome"]== 1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome  Pregnancies_high
# 0                       0.627   50        1                 0
# 2                       0.672   32        1                 1
# 4                       2.288   33        1                 0
# 6                       0.248   26        1                 0
# 8                       0.158   53        1                 0
# ..                        ...  ...      ...               ...
# 755                     1.057   37        1                 0
# 757                     0.258   52        1                 0
# 759                     0.278   66        1                 0
# 761                     0.403   43        1                 1
# 766                     0.349   47        1                 0
#
# [268 rows x 10 columns]

# %%
# 모든 변수에 대한 distplot을 그려 봅니다.

fig, axes= plt.subplots(nrows=4, ncols=2, figsize=(15,15))
for i, col_name in enumerate(cols[:-1]):
    row=i // 2
    col=i % 2
    sns.distplot(df_0[col_name], ax=axes[row][col])
    sns.distplot(df_1[col_name], ax=axes[row][col])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### 13.2.2 violinplot

# %%
# violinplot 으로 서브플롯을 그려봅니다.

fig, axes= plt.subplots(nrows=4, ncols=2, figsize=(15,15))
for i, col_name in enumerate(cols[:-1]):
    row=i // 2
    col=i % 2
    sns.violinplot(data=df, x="Outcome", y=col_name ,ax=axes[row][col])

# %% [markdown]
# #### 13.2.3 lmplot
# * 상관계수가 높은 두 변수에 대해 시각화 합니다.

# %%
# Glucose 와 Insulin 을 Outcome 으로 구분해 봅니다.
sns.lmplot(data=df, x="Glucose", y="Insulin", hue="Outcome")

# %%
# Insulin 수치가 0 이상인 데이터로만 그립니다.
# Glucose 와 Insulin 을 Outcome 으로 구분해 봅니다.
sns.lmplot(data=df[df["Insulin"]>0], x="Glucose", y="Insulin", hue="Outcome")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### 13.2.4 pairplot

# %%
# PairGrid 를 통해 모든 변수에 대해  Outcome 에 따른 scatterplot을 그려봅니다.
g=sns.PairGrid(df, hue="Outcome")
g.map(plt.scatter)

# %% [markdown]
# # 14 상관 분석
#         * r이 -1.0 과 -0.7 사이이면, 강한 음적 선형관계,
#         * r이 -0.7 과 -0.3 사이라면, 뚜렷한 음적 선형관계,
#         * r이 -0.3 과 -0.1 사이라면, 약한 음적 선형관계,
#         * r이 -0.1 과 +0.1 사이라면, 거의 무시될 수 있는 선형관계,
#         * r이 +0.1 과 +0.3 사이라면, 약한 양적 선형관계,
#         * r이 +0.3 과 +0.7 사이라면, 뚜렷한 양적 선형관계,
#         * r이 +0.7 과 +1.0 사이라면, 강한 양적 선형관계

# %%
df_matrix=df.iloc[:, :-2].replace(0, np.nan)
df_matrix["Outcome"]= df["Outcome"]
df_matrix.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 정답 값인 Outcome을 제외 하고 feature 로 사용할 컬럼들에 대해 0을 결측치로 만들어 줍니다.
# 상관계수를 구합니다.
df_corr=df_matrix.corr()
df_corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_1893d_row0_col0, #T_1893d_row1_col1, #T_1893d_row2_col2, #T_1893d_row3_col3, #T_1893d_row4_col4, #T_1893d_row5_col5, #T_1893d_row6_col6, #T_1893d_row7_col7, #T_1893d_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1893d_row0_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_1893d_row0_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_1893d_row0_col3 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_1893d_row0_col4, #T_1893d_row6_col8 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_1893d_row0_col5, #T_1893d_row2_col1, #T_1893d_row3_col1, #T_1893d_row4_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_1893d_row0_col6, #T_1893d_row2_col4, #T_1893d_row2_col6, #T_1893d_row2_col8, #T_1893d_row5_col7, #T_1893d_row6_col0, #T_1893d_row6_col1, #T_1893d_row6_col2, #T_1893d_row6_col3, #T_1893d_row7_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_1893d_row0_col7, #T_1893d_row1_col4 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_1893d_row0_col8, #T_1893d_row3_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_1893d_row1_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_1893d_row1_col2 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_1893d_row1_col3, #T_1893d_row2_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_1893d_row1_col5, #T_1893d_row4_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_1893d_row1_col6, #T_1893d_row5_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_1893d_row1_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_1893d_row1_col8 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_1893d_row2_col0, #T_1893d_row5_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_1893d_row2_col5, #T_1893d_row8_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_1893d_row2_col7 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_1893d_row3_col0, #T_1893d_row5_col8, #T_1893d_row8_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_1893d_row3_col2, #T_1893d_row8_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_1893d_row3_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_1893d_row3_col5 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_1893d_row3_col7, #T_1893d_row7_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_1893d_row3_col8 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_1893d_row4_col0, #T_1893d_row5_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_1893d_row4_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_1893d_row4_col3, #T_1893d_row7_col8 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_1893d_row4_col6, #T_1893d_row5_col0, #T_1893d_row6_col5, #T_1893d_row7_col4 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_1893d_row4_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_1893d_row4_col8, #T_1893d_row5_col6, #T_1893d_row8_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_1893d_row5_col3 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_1893d_row6_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_1893d_row6_col7 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_1893d_row7_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_1893d_row7_col2 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_1893d_row7_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_1893d_row7_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_1893d_row8_col1 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_1893d_row8_col5 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_1893d_row8_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_1893d_row8_col7 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# </style>
# <table id="T_1893d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1893d_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_1893d_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_1893d_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_1893d_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_1893d_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_1893d_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_1893d_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_1893d_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_1893d_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1893d_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_1893d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1893d_row0_col1" class="data row0 col1" >0.166329</td>
#       <td id="T_1893d_row0_col2" class="data row0 col2" >0.285013</td>
#       <td id="T_1893d_row0_col3" class="data row0 col3" >0.167298</td>
#       <td id="T_1893d_row0_col4" class="data row0 col4" >0.104081</td>
#       <td id="T_1893d_row0_col5" class="data row0 col5" >0.128207</td>
#       <td id="T_1893d_row0_col6" class="data row0 col6" >-0.006459</td>
#       <td id="T_1893d_row0_col7" class="data row0 col7" >0.550525</td>
#       <td id="T_1893d_row0_col8" class="data row0 col8" >0.268218</td>
#     </tr>
#     <tr>
#       <th id="T_1893d_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_1893d_row1_col0" class="data row1 col0" >0.166329</td>
#       <td id="T_1893d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1893d_row1_col2" class="data row1 col2" >0.223192</td>
#       <td id="T_1893d_row1_col3" class="data row1 col3" >0.228043</td>
#       <td id="T_1893d_row1_col4" class="data row1 col4" >0.581186</td>
#       <td id="T_1893d_row1_col5" class="data row1 col5" >0.232771</td>
#       <td id="T_1893d_row1_col6" class="data row1 col6" >0.137246</td>
#       <td id="T_1893d_row1_col7" class="data row1 col7" >0.267136</td>
#       <td id="T_1893d_row1_col8" class="data row1 col8" >0.494650</td>
#     </tr>
#     <tr>
#       <th id="T_1893d_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_1893d_row2_col0" class="data row2 col0" >0.285013</td>
#       <td id="T_1893d_row2_col1" class="data row2 col1" >0.223192</td>
#       <td id="T_1893d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1893d_row2_col3" class="data row2 col3" >0.226839</td>
#       <td id="T_1893d_row2_col4" class="data row2 col4" >0.098272</td>
#       <td id="T_1893d_row2_col5" class="data row2 col5" >0.289230</td>
#       <td id="T_1893d_row2_col6" class="data row2 col6" >-0.002805</td>
#       <td id="T_1893d_row2_col7" class="data row2 col7" >0.330107</td>
#       <td id="T_1893d_row2_col8" class="data row2 col8" >0.170589</td>
#     </tr>
#     <tr>
#       <th id="T_1893d_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_1893d_row3_col0" class="data row3 col0" >0.167298</td>
#       <td id="T_1893d_row3_col1" class="data row3 col1" >0.228043</td>
#       <td id="T_1893d_row3_col2" class="data row3 col2" >0.226839</td>
#       <td id="T_1893d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1893d_row3_col4" class="data row3 col4" >0.184888</td>
#       <td id="T_1893d_row3_col5" class="data row3 col5" >0.648214</td>
#       <td id="T_1893d_row3_col6" class="data row3 col6" >0.115016</td>
#       <td id="T_1893d_row3_col7" class="data row3 col7" >0.166816</td>
#       <td id="T_1893d_row3_col8" class="data row3 col8" >0.259491</td>
#     </tr>
#     <tr>
#       <th id="T_1893d_level0_row4" class="row_heading level0 row4" >Insulin</th>
#       <td id="T_1893d_row4_col0" class="data row4 col0" >0.104081</td>
#       <td id="T_1893d_row4_col1" class="data row4 col1" >0.581186</td>
#       <td id="T_1893d_row4_col2" class="data row4 col2" >0.098272</td>
#       <td id="T_1893d_row4_col3" class="data row4 col3" >0.184888</td>
#       <td id="T_1893d_row4_col

# %%
# 위에서 구한 상관계수를 heatmap으로 시각화 합니다.
plt.figure(figsize=(15,8))
sns.heatmap(df_corr, annot=True, vmax=1, vmin=-1, cmap="coolwarm")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Outcome 수치에 대한 상관계수만 모아서 봅니다.
df_corr["Outcome"]
# Out:
# Pregnancies                 0.268218
# Glucose                     0.494650
# BloodPressure               0.170589
# SkinThickness               0.259491
# Insulin                     0.303454
# BMI                         0.313680
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %% [markdown]
# ### 14.1 상관계수가 높은 변수끼리 보기

# %%
# insulin 과 Glucose 로 regplot 그리기
sns.regplot(data=df_matrix, x="Insulin", y="Glucose")
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>

# %%
# df_0 으로 결측치 처리한 데이터 프레임으로
# Insulin 과 Glucose 로 regplot 그리기
sns.regplot(data=df_0, x="Insulin", y="Glucose")
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>

# %%
sns.lmplot(data=df_matrix, x="Insulin", y="Glucose", hue="Outcome")

# %%
# Age 와 Pregnancies 로 regplot 그리기
sns.regplot(data=df, x="Age", y="Pregnancies")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Pregnancies'>

# %%
# Age 와 Pregnancies 로 lmplot 을 그리고 Outcome 에 따라 다른 색상으로 표현하기
sns.lmplot(data=df, x="Age", y="Pregnancies", hue="Outcome" , col="Outcome")
